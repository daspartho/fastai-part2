# %% [markdown]
# <a href="https://colab.research.google.com/github/daspartho/fastai-part2/blob/main/strikethrough_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch, logging
from pathlib import Path
from huggingface_hub import notebook_login
from diffusers import StableDiffusionPipeline

logging.disable(logging.WARNING)

if not (Path.home()/'.huggingface'/'token').exists(): notebook_login()

# %%
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16).to("cuda")
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]

# %%
prompt = "a photograph of a dry leaf"

# %%
torch.manual_seed(123)
pipe(prompt).images[0]
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6088692A10>

# %%
neg_prompt = "a photograph of a d̶r̶y̶  leaf"

# %%
torch.manual_seed(123)
pipe(neg_prompt).images[0]
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6087DB18D0>

# %%
torch.manual_seed(123)
pipe(prompt, negative_prompt=neg_prompt).images[0]
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F608717D190>
